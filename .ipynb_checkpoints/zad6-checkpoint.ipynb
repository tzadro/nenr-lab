# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib import axis
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Membership functions

# %%
input_file = './materijali/zad6-outputs/membership-functions.txt'
num_rules = 8
num_elements = 1001

# %%
yA = []
yB = []
with open(input_file, 'r') as f:
    x = np.fromstring(f.readline(), count=num_elements, sep=',')
    
    for i in range(num_rules):
        yA.append(np.fromstring(f.readline(), count=num_elements, sep=','))
        yB.append(np.fromstring(f.readline(), count=num_elements, sep=','))

# %%
for i in range(num_rules):
    plt.plot(x, yA[i], label='A', c='r')
    plt.plot(x, yB[i], label='B', c='b')
    plt.ylim(0, 1)
    plt.title('Rule ' + str(i + 1))
    plt.legend()
    plt.show()

# %% [markdown]
# ### Error

# %%
input_file = './materijali/zad6-outputs/error.txt'
num_elements = 81

# %%
with open(input_file, 'r') as f:
    xs = np.fromstring(f.readline(), count=num_elements, sep=',')
    ys = np.fromstring(f.readline(), count=num_elements, sep=',')
    zs = np.fromstring(f.readline(), count=num_elements, sep=',')

# %%
data_dict = {}
for x, y, z in zip(xs, ys, zs):
    data_dict[(x, y)] = z

x = np.arange(-4, 5, 1)
y = np.arange(-4, 5, 1)
X, Y = np.meshgrid(x, y)

Z = []

for a, b in zip(X, Y):
    z = []
    
    for xd, yd in zip(a, b):
        z.append(data_dict[(xd, yd)])
    
    Z.append(z)

Z = np.array(Z)
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('δ(x, y)')
ax.plot_wireframe(X, Y, Z)
plt.show()
